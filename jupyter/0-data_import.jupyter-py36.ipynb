# %% [markdown]
# # Data Import from a Remote Db2 Warehouse on Cloud Instance
#
# ## Overview
#
# This notebook provides an example which connects to a Db2 Warehouse service running on IBM Cloud.  It includes the steps required to set up the data connection within IBM Cloud Private for Data to the service.  In this example, the data is stored in three different tables within Db2 Warehouse representing different business unit geographies which control the data.  The primary steps in the flow include:
#
# - Read the data from the 3 tables in the cloud database.
# - Normalize the data columns so that all 3 geographies have a common format.
# - Merge the three tables into a single data set.
# - Output the resulting data set to a CSV file for downstream processing.
#
# ## Create a Db2 Warehouse on Cloud Instance and Set Up Connections
#
# A tutorial for creating a Db2 Warehouse instance on IBM Cloud is available and should be followed prior to running this notebook.  It includes steps to configure connections from this IBM Cloud Private for Data environment to the database.

# %% [markdown]
# ## Add Data Sets
#
# After the database has been configured and connections to it established, datasets can be added to the project.  First, from the main page of this project, select __"Data sets"__ and then __"Add Data Set"__.
#
# ---
# <img src="../misc/images/add_data_set.png" alt="Drawing" style="width: 900px;"/>
# <br>
#
# ---
#
# <br>
# <br>
#
# On the next menu, select __"Remote Data Set"__, __"Browse"__, and then your database name.  The three tables in the example database (EVENTS_EUR, EVENTS_USE, EVENTS_USW) will each need to be selected and assigned remote data set names of EUR, USE, and USW respectively.  These names will be used in the notebook's python code to read in the cooresponding table data.
#
# <img src="../misc/images/remote_data_set.png" alt="Drawing" style="width: 400px;"/>
# <br>
#
# ---
#
# <br>

# %% [markdown]
# After all of the data sets have been added to your project, you will see them listed as part of the _"Data Sets"_ assets as shown below.  You can now run the rest of this notebook to read the data from the database tables, join it into a single table, and write it out to a CSV file for processing in the remaining notebooks in this industry accelerator.
#
# ---
#
# <img src="../misc/images/final_data_sets.png" alt="Drawing" style="width: 1000px;"/>
# <br>
#
# ---

# %% [markdown]
# **Sample Materials, provided under license. <br>
# Licensed Materials - Property of IBM. <br>
# © Copyright IBM Corp. 2019. All Rights Reserved. <br>
# US Government Users Restricted Rights - Use, duplication or disclosure restricted by GSA ADP Schedule Contract with IBM Corp. <br>**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Connect to the Remote Database and Read the Data
#
# The following three cells connect the the DB2 Warehouse instance and pull the data from the three tables.  The code shown here is complete and will pull in the datasets configured as described above.  It was originally generated automatically for this notebook by following the __"Find Data"__ process as shown in the following diagram:
#
#
# ---
# <img src="../misc/images/insert_dataframe.png" alt="Drawing" style="width: 900px;"/>
# <br>
#
# ---
#
# <br>
# <br>

# %%
import dsx_core_utils, requests, jaydebeapi, os, io, sys
from pyspark.sql import SparkSession
import pandas as pd
df1 = None
dataSet = dsx_core_utils.get_remote_data_set_info('USW')
dataSource = dsx_core_utils.get_data_source_info(dataSet['datasource'])
if (sys.version_info >= (3, 0)):
  conn = jaydebeapi.connect(dataSource['driver_class'], dataSource['URL'], [dataSource['user'], dataSource['password']])
else:
  conn = jaydebeapi.connect(dataSource['driver_class'], [dataSource['URL'], dataSource['user'], dataSource['password']])
query = 'select * from "' + (dataSet['schema'] + '"."' if (len(dataSet['schema'].strip()) != 0) else '') +  dataSet['table'] + '"'

if (dataSet['query']):
    query = dataSet['query']
df1 = pd.read_sql(query, con=conn, parse_dates=['CUSTOMER_RELATIONSHIP_START_DATE',
                                 'CUSTOMER_SUMMARY_END_DATE', 'CUSTOMER_SUMMARY_START_DATE'])
print(df1.head())
# Out:
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLIED_TO_OFFER_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLY_TIME  \
# 0                                          56.662857
# 1                                          56.662857
# 2                                          56.662857
# 3                                          56.662857
# 4                                          56.662857
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_LAST_PRODUCT_OFFER_DATE  \
# 0                                                611
# 1                                                611
# 2                                                611
# 3                                                611
# 4                                                611
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_PRODUCT_OFFERED_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_PRODUCT_OWNED_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_SENTIMENT_SCORE  \
# 0                                           2.408571
# 1                                           2.408571
# 2                                           2.408571
# 3                                           2.408571
# 4                                           2.408571
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLIED_TO_OFFER_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLY_TIME  \
# 0                                           57.62117
# 1                                           57.62117
# 2                                           57.62117
# 3                                           57.62117
# 4                                           57.62117
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_LAST_PRODUCT_OFFER_DATE  \
# 0                                                713
# 1                                                713
# 2                                                713
# 3                                                713
# 4                                                713
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_PRODUCT_OFFERED_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                         ...                         \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#    CUSTOMER_ALIAS_RECENT_SYSTEM_LOAD_TIMESTAMP  \
# 0                                1553542044109
# 1                                1553542044109
# 2                                1553542044109
# 3                                1553542044109
# 4                                1553542044109
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_HIGH  \
# 0                                    1.0
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_LOW  \
# 0                                   NaN
# 1                                   NaN
# 2                                   2.0
# 3                                   NaN
# 4                                   NaN
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_MODERATE  \
# 0                                        NaN
# 1                                        3.0
# 2                                        2.0
# 3                                        1.0
# 4                                        3.0
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_VERY_LOW  \
# 0                                        1.0
# 1                                        NaN
# 2                                        NaN
# 3                                        1.0
# 4                                        NaN
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_GROWTH  \
# 0                                            1.0
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_INCOME  \
# 0                                            NaN
# 1                                            NaN
# 2                                            2.0
# 3                                            NaN
# 4                                            NaN
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_PLANNING  \
# 0                                              NaN
# 1                                              2.0
# 2                                              2.0
# 3                                              NaN
# 4                                              2.0
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_SECURE_GROWTH  \
# 0                                                NaN
# 1                                                1.0
# 2                                                NaN
# 3                                                1.0
# 4                                                1.0
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_SECURITY
# 0                                              1.0
# 1                                              NaN
# 2                                              NaN
# 3                                              1.0
# 4                                              NaN
#
# [5 rows x 315 columns]

# %%
import dsx_core_utils, requests, jaydebeapi, os, io, sys
from pyspark.sql import SparkSession
import pandas as pd
df2 = None
dataSet = dsx_core_utils.get_remote_data_set_info('USE')
dataSource = dsx_core_utils.get_data_source_info(dataSet['datasource'])
if (sys.version_info >= (3, 0)):
  conn = jaydebeapi.connect(dataSource['driver_class'], dataSource['URL'], [dataSource['user'], dataSource['password']])
else:
  conn = jaydebeapi.connect(dataSource['driver_class'], [dataSource['URL'], dataSource['user'], dataSource['password']])
query = 'select * from "' + (dataSet['schema'] + '"."' if (len(dataSet['schema'].strip()) != 0) else '') +  dataSet['table'] + '"'

if (dataSet['query']):
    query = dataSet['query']
df2 = pd.read_sql(query, con=conn, parse_dates=['CUSTOMER_RELATIONSHIP_START_DATE',
                                 'CUSTOMER_SUMMARY_END_DATE', 'CUSTOMER_SUMMARY_START_DATE'])
print(df2.head())
# Out:
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLIED_TO_OFFER_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLY_TIME  \
# 0                                          56.662857
# 1                                          56.662857
# 2                                          56.662857
# 3                                          56.662857
# 4                                          56.662857
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_LAST_PRODUCT_OFFER_DATE  \
# 0                                                611
# 1                                                611
# 2                                                611
# 3                                                611
# 4                                                611
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_PRODUCT_OFFERED_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_PRODUCT_OWNED_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_SENTIMENT_SCORE  \
# 0                                           2.408571
# 1                                           2.408571
# 2                                           2.408571
# 3                                           2.408571
# 4                                           2.408571
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLIED_TO_OFFER_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLY_TIME  \
# 0                                           57.62117
# 1                                           57.62117
# 2                                           57.62117
# 3                                           57.62117
# 4                                           57.62117
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_LAST_PRODUCT_OFFER_DATE  \
# 0                                                713
# 1                                                713
# 2                                                713
# 3                                                713
# 4                                                713
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_PRODUCT_OFFERED_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                         ...                         \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#    CUSTOMER_ALIAS_RECENT_SYSTEM_LOAD_TIMESTAMP  \
# 0                                1553542044109
# 1                                1553542044109
# 2                                1553542044109
# 3                                1553542044109
# 4                                1553542044109
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_HIGH  \
# 0                                    NaN
# 1                                    1.0
# 2                                    1.0
# 3                                    1.0
# 4                                    NaN
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_LOW  \
# 0                                   1.0
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_MODERATE  \
# 0                                        NaN
# 1                                        2.0
# 2                                        1.0
# 3                                        2.0
# 4                                        1.0
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_VERY_LOW  \
# 0                                        2.0
# 1                                        NaN
# 2                                        1.0
# 3                                        NaN
# 4                                        2.0
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_GROWTH  \
# 0                                            NaN
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            NaN
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_INCOME  \
# 0                                            1.0
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_PLANNING  \
# 0                                              NaN
# 1                                              1.0
# 2                                              1.0
# 3                                              1.0
# 4                                              NaN
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_SECURE_GROWTH  \
# 0                                                NaN
# 1                                                1.0
# 2                                                NaN
# 3                                                1.0
# 4                                                1.0
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_SECURITY
# 0                                              2.0
# 1                                              NaN
# 2                                              1.0
# 3                                              NaN
# 4                                              2.0
#
# [5 rows x 315 columns]

# %%
import dsx_core_utils, requests, jaydebeapi, os, io, sys
from pyspark.sql import SparkSession
import pandas as pd
df3 = None
dataSet = dsx_core_utils.get_remote_data_set_info('EUR')
dataSource = dsx_core_utils.get_data_source_info(dataSet['datasource'])
if (sys.version_info >= (3, 0)):
  conn = jaydebeapi.connect(dataSource['driver_class'], dataSource['URL'], [dataSource['user'], dataSource['password']])
else:
  conn = jaydebeapi.connect(dataSource['driver_class'], [dataSource['URL'], dataSource['user'], dataSource['password']])
query = 'select * from "' + (dataSet['schema'] + '"."' if (len(dataSet['schema'].strip()) != 0) else '') +  dataSet['table'] + '"'

if (dataSet['query']):
    query = dataSet['query']
df3 = pd.read_sql(query, con=conn, parse_dates=['CUSTOMER_RELATIONSHIP_START_DATE',
                                 'CUSTOMER_SUMMARY_END_DATE', 'CUSTOMER_SUMMARY_START_DATE'])
print(df3.head())
# Out:
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLIED_TO_OFFER_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLY_TIME  \
# 0                                          56.662857
# 1                                          56.662857
# 2                                         111.000000
# 3                                          42.000000
# 4                                          56.662857
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_LAST_PRODUCT_OFFER_DATE  \
# 0                                                611
# 1                                                611
# 2                                               1162
# 3                                                235
# 4                                                611
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_PRODUCT_OFFERED_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_PRODUCT_OWNED_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_SENTIMENT_SCORE  \
# 0                                           2.408571
# 1                                           2.408571
# 2                                           5.000000
# 3                                           1.000000
# 4                                           2.408571
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLIED_TO_OFFER_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLY_TIME  \
# 0                                           57.62117
# 1                                           57.62117
# 2                                           57.62117
# 3                                           57.62117
# 4                                           57.62117
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_LAST_PRODUCT_OFFER_DATE  \
# 0                                                713
# 1                                                713
# 2                                                713
# 3                                                713
# 4                                                713
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_PRODUCT_OFFERED_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                         ...                         \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#    CUSTOMER_ALIAS_RECENT_SYSTEM_LOAD_TIMESTAMP  \
# 0                                1553542044109
# 1                                1553542044109
# 2                                1553542044109
# 3                                1553542044109
# 4                                1553542044109
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_HIGH  \
# 0                                    1.0
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    1.0
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_LOW  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_MODERATE  \
# 0                                        NaN
# 1                                        3.0
# 2                                        3.0
# 3                                        3.0
# 4                                        NaN
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_VERY_LOW  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        1.0
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_GROWTH  \
# 0                                            1.0
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            1.0
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_INCOME  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_PLANNING  \
# 0                                              NaN
# 1                                              2.0
# 2                                              2.0
# 3                                              2.0
# 4                                              NaN
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_SECURE_GROWTH  \
# 0                                                NaN
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                NaN
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_SECURITY
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              1.0
#
# [5 rows x 315 columns]

# %% [markdown]
# ## Combine the Tables
#
# This code sequence renames the columns of each of the tables to a uniform schema and then concatenates them into a single dataframe.

# %%
frames = [df1, df2, df3]
df_raw = pd.concat(frames)
print("Merged Data set:")
print(df_raw.head())
print('Merged data has ' + str(df_raw.shape[0]) + ' rows and ' + str(df_raw.shape[1]) + ' columns.')
# Out:
# Merged Data set:
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLIED_TO_OFFER_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLY_TIME  \
# 0                                          56.662857
# 1                                          56.662857
# 2                                          56.662857
# 3                                          56.662857
# 4                                          56.662857
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_LAST_PRODUCT_OFFER_DATE  \
# 0                                                611
# 1                                                611
# 2                                                611
# 3                                                611
# 4                                                611
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_PRODUCT_OFFERED_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_PRODUCT_OWNED_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_MANAGEDPORTFOLIO_CUSTOMER_PRODUCT_SUMMARY_SENTIMENT_SCORE  \
# 0                                           2.408571
# 1                                           2.408571
# 2                                           2.408571
# 3                                           2.408571
# 4                                           2.408571
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLIED_TO_OFFER_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_LAST_CUSTOMER_REPLY_TIME  \
# 0                                           57.62117
# 1                                           57.62117
# 2                                           57.62117
# 3                                           57.62117
# 4                                           57.62117
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_LAST_PRODUCT_OFFER_DATE  \
# 0                                                713
# 1                                                713
# 2                                                713
# 3                                                713
# 4                                                713
#
#    PID_BROKERAGE_CUSTOMER_PRODUCT_SUMMARY_PRODUCT_OFFERED_INDICATOR  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                         ...                         \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#    CUSTOMER_ALIAS_RECENT_SYSTEM_LOAD_TIMESTAMP  \
# 0                                1553542044109
# 1                                1553542044109
# 2                                1553542044109
# 3                                1553542044109
# 4                                1553542044109
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_HIGH  \
# 0                                    1.0
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_LOW  \
# 0                                   NaN
# 1                                   NaN
# 2                                   2.0
# 3                                   NaN
# 4                                   NaN
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_MODERATE  \
# 0                                        NaN
# 1                                        3.0
# 2                                        2.0
# 3                                        1.0
# 4                                        3.0
#
#    NUM_ACCOUNTS_WITH_RISK_TOLERANCE_VERY_LOW  \
# 0                                        1.0
# 1                                        NaN
# 2                                        NaN
# 3                                        1.0
# 4                                        NaN
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_GROWTH  \
# 0                                            1.0
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_INCOME  \
# 0                                            NaN
# 1                                            NaN
# 2                                            2.0
# 3                                            NaN
# 4                                            NaN
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_PLANNING  \
# 0                                              NaN
# 1                                              2.0
# 2                                              2.0
# 3                                              NaN
# 4                                              2.0
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_SECURE_GROWTH  \
# 0                                                NaN
# 1                                                1.0
# 2                                                NaN
# 3                                                1.0
# 4                                                1.0
#
#    NUM_ACCOUNTS_WITH_INVESTMENT_OBJECTIVE_SECURITY
# 0                                              1.0
# 1                                              NaN
# 2                                              NaN
# 3                                              1.0
# 4                                              NaN
#
# [5 rows x 315 columns]
# Merged data has 1000 rows and 315 columns.

# %% [markdown]
# ## Output the Final Dataset
#
# Finally we output the dataset into a CSV file which is stored locally for processing in the subsequent steps of this application.

# %%
df_raw.to_csv('../datasets/customer_full_summary_latest_combined.csv', index=False)
